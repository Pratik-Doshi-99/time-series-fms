# %%
import torch
import numpy as np

# %%
data = torch.load('./test_dir/preprocessed_data_1.pt', weights_only=False)

# %%
data.keys()
# Out:
# dict_keys(['tensors', 'metadata', 'preprocessor_attrs'])

# %%
data['metadata']
# Out:
# [{'min_val': np.float64(-134.14158753921072),
#   'max_val': np.float64(-2.6548629997399704),
#   'mean_val': np.float64(-65.8022920746982),
#   'std_val': np.float64(37.977038257644864)},
#  {'min_val': np.float64(-4.684511537872167),
#   'max_val': np.float64(176.80979981746677),
#   'mean_val': np.float64(87.87369007026162),
#   'std_val': np.float64(52.309959920806335)},
#  {'min_val': np.float64(-126.60705322751843),
#   'max_val': np.float64(4.732932763099815),
#   'mean_val': np.float64(-59.914515265907845),
#   'std_val': np.float64(38.300922478321745)},
#  {'min_val': np.float64(-89.92439745780449),
#   'max_val': np.float64(-2.4716003037163334),
#   'mean_val': np.float64(-46.80975363289365),
#   'std_val': np.float64(24.712577043632926)},
#  {'min_val': np.float64(-29.778659379859207),
#   'max_val': np.float64(10.694364655471972),
#   'mean_val': np.float64(-9.514335192357132),
#   'std_val': np.float64(11.449784458747374)},
#  {'min_val': np.float64(-33.54055743379129),
# ...

# %%
len(data['metadata']), len(data['tensors']), data['preprocessor_attrs']
# Out:
# (1024,
#  1024,
#  {'num_classes': 100,
#   'add_bos': False,
#   'add_eos': False,
#   'range_min': 0,
#   'range_max': 99,
#   'range_precision': 1.0,
#   'BOS_TOKEN': 100,
#   'EOS_TOKEN': 101,
#   'PAD_TOKEN': 102})
